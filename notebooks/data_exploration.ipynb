# %%
import pandas as pd

# %%
customers = pd.read_csv("../data/raw/customer.csv")
shipments = pd.read_csv("../data/raw/shipment.csv")
performance = pd.read_csv("../data/raw/logistics_performance.csv")

# %%
print("Customers:", customers.shape)
print("Shipments:", shipments.shape)
print("Performance:", performance.shape)
# Out:
# Customers: (750, 12)
# Shipments: (728, 12)
# Performance: (100, 8)

# %%
customers.head()
# Out:
#   customer_id acquisition_date  acquisition_cost_usd market_segment  \
# 0    CUST-001       2024-01-05                   850  North America
# 1    CUST-002       2024-01-06                   920         Europe
# 2    CUST-003       2024-01-07                   880   Asia-Pacific
# 3    CUST-004       2024-01-08                   790  North America
# 4    CUST-005       2024-01-09                   950         Europe
#
#   supplier_id  order_id  order_date  order_value_usd payment_date  \
# 0       SUP-A  ORD-1001  2024-01-15            12500   2024-02-18
# 1       SUP-B  ORD-1002  2024-01-18             8500   2024-02-25
# 2       SUP-C  ORD-1003  2024-01-20            21000   2024-03-01
# 3       SUP-A  ORD-1004  2024-01-22             7500   2024-02-28
# 4       SUP-D  ORD-1005  2024-01-25            15000   2024-03-05
#
#    satisfaction_score  support_tickets  lead_time_days
# 0                   4                1              14
# ...

# %%
shipments.head()
# Out:
#      shipment_id    type        date      product_category    origin  \
# 0  SHP-2024-0001  Export  2024-01-02           Electronics    Mumbai
# 1  SHP-2024-0002  Import  2024-01-03              Textiles  Shanghai
# 2  SHP-2024-0003  Export  2024-01-04        Consumer Goods    Mumbai
# 3  SHP-2024-0004  Import  2024-01-05  Industrial Equipment   Hamburg
# 4  SHP-2024-0005  Export  2024-01-06           Electronics    Mumbai
#
#   O_Country destination D_Country   value  freight_cost  \
# 0     India    New York       USA   85000        4250.0
# 1     China      Mumbai     India  120000        6000.0
# 2     India      London        UK   45000        2250.0
# 3   Germany      Mumbai     India  250000       12500.0
# 4     India       Tokyo     Japan   95000        4750.0
#
#   customs_clearance_time_days delivery_status
# 0                         2.1         On-Time
# 1                         3.5         On-Time
# 2                         1.8         On-Time
# ...

# %%
performance.head()
# Out:
#          date         region            carrier  shipments_processed  \
# 0  2024-06-01  North America           FastShip                 1500
# 1  2024-06-01         Europe      GlobalConnect                 1200
# 2  2024-06-01   Asia-Pacific       OceanExpress                 2100
# 3  2024-06-01  North America  ReliableLogistics                  900
# 4  2024-06-02  North America           FastShip                 1450
#
#    delay_hours_avg  fuel_price_usd_per_barrel  warehouse_utilization_percent  \
# 0              2.5                       78.2                             85
# 1              1.8                       79.5                             75
# 2              4.1                       81.1                             92
# 3              1.2                       78.2                             60
# 4              2.8                       78.5                             86
#
#    damage_claims_count
# 0                    5
# 1                    2
# ...

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           750 non-null    str
#  1   acquisition_date      750 non-null    str
#  2   acquisition_cost_usd  750 non-null    int64
#  3   market_segment        750 non-null    str
#  4   supplier_id           750 non-null    str
#  5   order_id              750 non-null    str
#  6   order_date            750 non-null    str
#  7   order_value_usd       750 non-null    int64
#  8   payment_date          750 non-null    str
#  9   satisfaction_score    750 non-null    int64
#  10  support_tickets       750 non-null    int64
#  11  lead_time_days        750 non-null    int64
# dtypes: int64(5), str(7)
# memory usage: 70.4 KB

# %%
shipments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   shipment_id                  728 non-null    str
#  1   type                         728 non-null    str
#  2   date                         728 non-null    str
#  3   product_category             728 non-null    str
#  4   origin                       728 non-null    str
#  5   O_Country                    728 non-null    str
#  6   destination                  728 non-null    str
#  7   D_Country                    728 non-null    str
#  8   value                        728 non-null    int64
#  9   freight_cost                 728 non-null    float64
#  10  customs_clearance_time_days  728 non-null    str
#  11  delivery_status              704 non-null    str
# dtypes: float64(1), int64(1), str(10)
# memory usage: 68.4 KB

# %%
performance.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           100 non-null    str
#  1   region                         100 non-null    str
#  2   carrier                        100 non-null    str
#  3   shipments_processed            100 non-null    int64
#  4   delay_hours_avg                100 non-null    float64
#  5   fuel_price_usd_per_barrel      100 non-null    float64
#  6   warehouse_utilization_percent  100 non-null    int64
#  7   damage_claims_count            100 non-null    int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 6.4 KB

# %%
customers.isnull().sum()
# Out:
# customer_id             0
# acquisition_date        0
# acquisition_cost_usd    0
# market_segment          0
# supplier_id             0
# order_id                0
# order_date              0
# order_value_usd         0
# payment_date            0
# satisfaction_score      0
# support_tickets         0
# lead_time_days          0
# dtype: int64

# %%
shipments.isnull().sum()
# Out:
# shipment_id                     0
# type                            0
# date                            0
# product_category                0
# origin                          0
# O_Country                       0
# destination                     0
# D_Country                       0
# value                           0
# freight_cost                    0
# customs_clearance_time_days     0
# delivery_status                24
# dtype: int64

# %%
performance.isnull().sum()
# Out:
# date                             0
# region                           0
# carrier                          0
# shipments_processed              0
# delay_hours_avg                  0
# fuel_price_usd_per_barrel        0
# warehouse_utilization_percent    0
# damage_claims_count              0
# dtype: int64

# %%
print("customer duplicates:",customers.duplicated().sum())
print("shipments duplicates:",shipments.duplicated().sum())
print("performance duplicates:",performance.duplicated().sum())
# Out:
# customer duplicates: 0
# shipments duplicates: 0
# performance duplicates: 0

# %%
customers.shape
shipments.shape
performance.shape
# Out:
# (100, 8)

# %%
shipments["customs_clearance_time_days"] = pd.to_numeric(
    shipments["customs_clearance_time_days"],
    errors="coerce"
)

shipments["customs_clearance_time_days"] = (
    shipments["customs_clearance_time_days"]
    .fillna(shipments["customs_clearance_time_days"].median())
)

# %%
shipments["customs_clearance_time_days"] = shipments["customs_clearance_time_days"].fillna(
    shipments["customs_clearance_time_days"].median()
)

# %%
shipments["customs_clearance_time_days"] = pd.to_numeric(
    shipments["customs_clearance_time_days"],
    errors="coerce"
)

# %%
median_clearance_time = shipments["customs_clearance_time_days"].median()

shipments["customs_clearance_time_days"] = (
    shipments["customs_clearance_time_days"]
    .fillna(median_clearance_time)
)

# %%
print(shipments["customs_clearance_time_days"].dtype)
print(shipments["customs_clearance_time_days"].isnull().sum())
print("median used:", median_clearance_time)
# Out:
# float64
# 0
# median used: 3.75

# %%
shipments["customs_clearance_time_days"].isnull().sum()
# Out:
# np.int64(0)

# %%
from pathlib import Path

processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

# %%
customers.to_csv(
    processed_dir / "customers_clean.csv",
    index=False
)

# %%
shipments.to_csv(

    processed_dir / "shipments_clean.csv",

    index=False

)

# %%
performance.to_csv(

    processed_dir / "performance_clean.csv",

    index=False

)
